# %%
import pandas as pd

pd.set_option('display.max_columns', 45)
pd.set_option('display.max_rows', 100)

    

excel = pd.read_excel('../data/5402.xlsx')



# Format
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.translate({ord(i): '' for i in ',;'})
excel['Don vi doi tac'] = excel['Don vi doi tac'] + ' '

excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace('( ', '(', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' )', ')', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(')', ') ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace('(', ' (', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace('-', ' - ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace('&', ' & ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' .LTD', ' LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' CO.LTD', ' CO. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' CO LTD', ' CO. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' CO.LTD.', ' CO. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' CO . LTD', ' CO. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' CO. LTD.', ' CO. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' CO. LTD .', ' CO. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' PVT.LTD', ' PVT. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' LTD.', ' LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' PTE', ' PTE.', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' G.A.', ' G.A', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' FTY.LTD', ' FTY. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' FTY LTD', ' FTY. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' IND. ', ' IND ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' KUN SHAN ', ' KUNSHAN ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' AND ', ' & ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' SDN BHD', ' SDN. BHD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' SDN.BHD', ' SDN. BHD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' SDN. BHD.', ' SDN. BHD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' SDN.BHD.', ' SDN. BHD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' SDN. BHD .', ' SDN. BHD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' EXP.CO.LTD', ' EXP CO. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' COLTD', ' CO. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' PTE LTD', ' PTE. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' PTE.LTD', ' PTE. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' MFG.CO.LTD', ' MFG. CO. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' MFG. CO.LTD', ' MFG. CO. LTD', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' PETROCHEMICALS.', ' PETROCHEMICALS', regex=False)

# Spelling Errors
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' LIMTED ', ' LIMITED ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' SYNTHETICES ', ' SYNTHETICS ')
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' TRAADING ', ' TRADING ')
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' COPORATION ', ' CORPORATION ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace('SHANG HAI', 'SHANGHAI', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' EXPORT', ' EXPORT ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' FIRNITURE', ' FURNITURE', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' MATERIAL ', ' FURNITURE', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' MATERIALSS ', ' MATERIALS ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' INT L ', " INT'L ", regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace('ZHE JIANG', 'ZHEJIANG', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' INDODRAMA ', ' INDORAMA ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' FIBRE ', ' FIBER ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' CORPERATION ', ' CORPORATION ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' INTERNATIONALHOLDINGS ', ' INTERNATIONAL HOLDINGS ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' TEXTTILE ', ' TEXTILE ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' TEXILE ', ' TEXTILE ', regex=False)
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' FEBERS ', ' FIBERS ', regex=False)

# Remove multiple space with one space

excel['Don vi doi tac'] = [' '.join(x.split()) for x in excel['Don vi doi tac']]
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.rstrip('.')

# For some reason, it's here...
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace('VIET NAM', 'VIETNAM')
excel['Don vi doi tac'] = excel['Don vi doi tac'].str.replace(' VIETNAM', ' (VIETNAM)')

excel.to_excel('../output/testing.xlsx')

words_to_remove = [
    ' CO.',
    'CONG TY',
    'CO PHAN',
    'TNHH',
    ' CTY',
    ' PTE.',
    ' LTD',
    ' LIMITED',
    ' INC',
    ' CORPORATION',
    " INT'L",
    ' COMPANY',
    ' FTY'
]
from functools import reduce

excel['TEMP'] = reduce(lambda a, b: a.str.replace(b, ''), [excel['Don vi doi tac']] + words_to_remove)
excel['TEMP'] = excel['TEMP'].str.rstrip('.')
excel['TEMP'] = [' '.join(x.split()) for x in excel['TEMP']]

excel['TEMP'].unique()


excel_count = len(excel.index)
for index, row in excel.iterrows():
    if index < excel_count - 1:
        current_cell = (excel['TEMP'].iloc[index].split())
        next_cell = (excel['TEMP'].iloc[index + 1].split())
        if len(set(current_cell).intersection(next_cell)) / len(current_cell) > 0.5 or len(set(current_cell).intersection(next_cell)) / len(next_cell) >= 0.5:
            excel.at[index + 1,'TEMP'] = excel.at[index,'TEMP']
# Out:
# C:\Users\Thinh\AppData\Local\Temp/ipykernel_7604/2627230077.py:99: FutureWarning: The default value of regex will change from True to False in a future version.
#   excel['TEMP'] = reduce(lambda a, b: a.str.replace(b, ''), [excel['Don vi doi tac']] + words_to_remove)

# %%
for x in excel['TEMP'].unique():
    print(x)
# Out:
# EVEREST TEXTILE
# G.A RESOURCES
# K & V GLOBAL
# KYORITSU
# LARISCO
# NEW SPACIAL INTERNATIONAL
# SHINKONG SYNTHETIC FIBERSPORATION
# 7TH STREET APPAREL
# ACME YARNS PRIVATE
# ACS
# ACTIVE STAR GLOBALP
# AIKNIT INTERNATIONAL TAIWAN BRANCH
# AIR RICH TRADING DEVELOPMENT
# ALL SEVEN TEXTILE
# AMBICASEEDS
# AMERICAN & EFIRD (HK)
# ANDAO TEXTILE
# ANHUI NEW FORDING THREAD
# AQUAFIL O'MARA
# ARISTA GLOBAL
# ARMOTEC
# ART - YARN EXPORT S (INDIA) PVT
# ASAHI KASEI ADVANCEPORATION
# ASAHI SHOJI
# ASIA BEST INDUSTRIALP
# ASIATIC FIBERPORATION
# ATNTPORATION
# AUSPRING
# AVANTI EXIM
# AVERY DENNISON RIS ITALIA SRL
# AYM SYNTEX
# B. M. HOUSE (INDIA)
# BAUFNC
# BEEBONG
# BEEKAYLON SYNTHETICS PVT
# BELLAVIA RICAMI S.P.A
# BIGPORATION
# BILLION INDUSTRIAL (VIETNAM)
# BINZHOU WEIQIAO SCIENCE & TECHNOLOGY INDUSTRIAL PARK
# BONATEX
# BOOMIN ENTERPRISE
# BROS MACAOMERCIAL OFFSHORE
# CHAINHOME ENTERPRISE
# CHANGSHU WONDERFUL IMPORT & EXPORT
# CHANGZHOU DEXIANG INTERNATIONAL TRANSPORTATION
# CHANGZHOU FOREIGN TRADEP
# CHARGER ENTERPRISE
# CHARMING PRINTING (BOLUO)
# CHEENG SHYNGMERCE
# CHELSY TEXTILES
# CHEN TAI INTERNATIONAL INVESTMENT
# CHEN - E MACHINERY
# CHENSTAR
# CHENSTAR/FUFENG (HONGKONG) INDUSTRY
# CHEWON TEXTURED
# CHI BIEN FIBER
# CHI NHANHG TYPHAN SOI THE KY
# CHIEN YI ENTERPRISE
# CHORI (CHINA)
# CHORI SEC.0561
# CHORI SEC.0655
# CHORI SEC.0688
# CHORI SEC.688
# CHORI
# CHUANGLAI FIBER (FOSHAN)
# CHUN YU RIBBON ENT
# CHUNG SHING TEXTILE MARKETING
# EAST SUCCESS ACCESSORIES
# EDK
# ELITE TEXTILE (HANGZHOU)
# E - MART ENTERPRISE
# EUNSOL CHEMICAL
# EURO VISTAA (INDIA)
# EUTEX ENTERPRISE
# EVER TEXTILE ENTERPRISEPANY
# EVERPIA KOREA
# EVERST TEXTILE
# EVERWELL TEX
# EXCELTEXLIMITED
# EXTRA EXPECTATION
# FABIA
# FABIALACE
# FAIRTOP
# FAR EASTERN INDUSTRIES (SHANGHAI)
# FAR EASTERN NEW CENTURY
# FAR EASTERN POLYTEX (VIETNAM)
# FENGJIATEX (HK)
# FERRET TRADING (SUZHOU)
# FIBER TECH (SHANGHAI)
# FILMAN SRL
# FILSPEC
# FORERUN TRADING
# FORMOSA TAFFETA
# FORTUNE - VICTOR TEXTILEP
# FOSHAN NANHAI LISHUI CHEMICAL FIBER
# FOSHAN RUHONG TEXTILE
# FOSHAN ZHONGFANG INTERCONNECT TECHNOLOGY
# FUJIAN BAIKAI TEXTILE CHEMICAL FIBER INDUSTRY
# FUJIAN BETTERLIFE SUPPLY CHAIN MANAGEMENT
# FUJIAN BILLION POLYMERIZATION FIBER TECHNOLOGY INDUSTRIAL
# FUJIAN CYCLONE TRADING
# FUJIAN JINFENG IMP. & EXP
# FUJIAN JINHAOSHENG TEXTILE
# FUJIAN JINJIANG HUAMIN IMP. & EXP
# FUJIAN JINLUN FIBER SHAREHOLDINGPANY
# FUJIAN LITCHI TRADE
# FUJIAN NEWMARK INDUSTRIAL
# FUJIAN ZHENGQI HIGH - TECH FIBER TECHNOLOGY
# FUJIFILMPORATION
# FUJII
# FULL REACH INTERNATIONAL
# FULLXIN GROUP
# FUNG ANPORATION
# FURNIWEB MANUFACTURING SDN. BHD
# FUTURE TECH
# FUZHOU SOURCING GOLDEN INTERNATIONAL
# G.A RESOURCES/ NANTONG SHUNBANG CHEMICAL
# G.A RESOURCES/ SUZHOU FINETEX NEW METERIAL
# G.A RESOURCES/ TONGXIANG ZHONGCHEN CHEMICAL FIBER
# G.A. RESOURCES
# G.A. RESOURCES/ JIANGSU GUOWANG HIGH - TECHNIQUE FIBER
# GAON KNIT
# GATHER SHINE
# GEEN HOPANY
# GELAN TEXTILE IND
# GEM & CO
# GENIAL INTERNATIONAL
# GLOBAL AMS
# GLOBAL PLANNING
# GLOBAL SPANDEX
# GLOBAL STATE LLC
# GLOVELAND TECHNOLOGY
# GO FORWARD GLOBAL
# GOLD LONG JOHN INTERNATIONAL
# GOLD LONG JOHN/PHAN SOI THE KY
# GOLD LONG JOHN/ HUNG NGHIEP FORMOSA
# GOLD LONG JOHN/FAR EASTERN POLYTEX (VIETNAM)
# GOLDEN ARCH INTER NATIONALP
# GOLDEN STEED GLOBAL INVESTMENTS
# GOOD EXCESS
# GREAT CHEMICAL
# GSI CREOS
# GSI CREOSPORATION
# GUANGDONG DHOMA INDUSTRYPANY
# GUANGDONGXINHUIMEIDAJINLUNGUFENYOUXIANGONGSI
# GUANGXI DONGXING CITY DINGFENG TRADE
# GUANGXI PINGXIANG HUA SHUN INTL TRADING
# GUANGXI PINGXIANG ZHONGYUE IMPORT & EXPORT TRADE
# GUANGZHOU CITY PANYU TIN MEI DYEING
# GUANGZHOU FU DE LU TRADING
# GUANGZHOU GUNZETAL
# GUANGZHOU W.H INT TRADE
# GUANGZHOU ZERBAO TRADING
# GUNZETAL (SHANGHAI)
# GUO JI JIN RONG DA SHAD ZUO 5 CENG ZHONG GUO YOU DIAN QI CAI JI TUAN Y
# GUOXIN INFU
# GUXIANDAO INDUSTRIAL FIBER
# GWANGMYEONG CLEAN
# GYEONGWON FNV
# HAINING FAN FEI TRADINGPANY
# HAINING YIYI FURNITURE
# HAKUSAN DYEING & FINISHING
# HALEAD (H.K)
# HAN SUNG HARAM
# HANA INDUSTRIALPANY
# HANGZHOU ALEAD RUBBER & PLASTIC PRODUCTS
# HANGZHOU ANDAO TEXTILE
# HANGZHOU ANTONG CHEMICAL FIBER
# HANGZHOU CHYS IMPORT & EXPORT
# HANGZHOU JISHENG NEW FURNITURECO
# HANGZHOU KAILI CHEMICAL FIBERPANY
# HANGZHOU KANGXING TEXTILE
# HANGZHOU KINGS CHEMICAL FIBER SALES
# HANGZHOU LANFA TEXTILE
# HANGZHOU QINGYUN HOLDING GROUP
# HANGZHOU SAKURA THREAD
# HANGZHOU SHUYUAN IMPORT & EXPORT
# HANGZHOU TITA INDUSTRY
# HANGZHOU UNITED TEXTILE IMPORT & EXPORT
# HANGZHOU XING YI NEW FURNITURECO
# HANGZHOU YONGSHENG HIGH POLYMER FIBER
# HANGZHOU YUCHENG NEW FURNITURETECHNOLOGY
# HANGZHOU ZHONGCAI CHEMICAL FIBER
# HANGZHOU ZHONGCAI TEXTILE
# HANJIN TEXTILE
# HANSOLL TEXTILE
# HANSUNG WOOLEN TEXTILE
# HAO YANG KNITTEDPANY
# HAYABUSA
# HE MEI XING YEPANY
# HEBEI LIKE TEXTILE
# HENRIETTA GARMENT ACCESSORIESCO
# HERACLIDSPANY
# HERNG FA INDUSTRIAL
# HE - TEX HOLDINGS
# HIGHCHEM (SHANGHAI) TRADING
# HIP SHING DEVELOPMENT
# HK CHALLENGER TRADE
# HK M & L MARINE INTERNATIONAL
# HOME BEST INFORMATION TECHNOLOGY (SHANGHAI)
# HON SHINP
# HONG KONG CHENGXIE INDUSTRY
# HONG KONG MIN WIE TRADING
# HONG KONG TACHIBANA ELECTRONICS
# HONG YI FIBER IND
# HONGKONG RAINBOW TEXTILE
# HONGYI FIBER IND.CO.LTD
# HONGYU PLASTICS STRING FACTORY
# HSIAO - WEI - LIN
# HSING YONG HO ENTERPRISE
# HUA FENG GROUP
# HUA GANG INTERNATIONAL
# HUAFON CHONGQING SPANDEX
# HUAIAN DEFANG APPAREL
# HUAIAN GOLDEN RIBBON DYEING
# HUBEI WELLJOY IMPORT & EXPORT TRADING
# HUGE ROCK TEXTILE
# HUIZHOU RITONG YARNPANY
# ORIENT INTERNATIONAL HOLDING SHANGHAI HOMETEX
# ORIENTAL INDUSTRIES (SUZHOU)
# P NPORATION/GS
# P NPORATION/KT
# PACIFIC EQUIPMENT & MATERIALS
# PACIFIC TEXTILES
# PALLAVA TEXTILES (P)
# PANKOPORATION
# PANNYTEXP
# PAO SHING INDUSTRIAL
# PATEL INTERNATIONAL
# PATODIA OVERSEAS EXPORT S LLP
# PAXAR (CHINA)
# PCGT
# PEAK LEADER (GUANGZHOU)
# PINGXIANG CITY HOLLY IMPORT & EXPORT TRADE
# PINGXIANG RUIXIANG IMP & EXP TRADE
# PIONEER ELASTIC (HONG KONG)
# POLYGENTA TECHNOLOGIES
# POLYTEKS TEKSTIL SANAYI ARASTIRMA VE EGITIM A.S
# POWER WIN PLASTICAL PRODUCTS (S.Z.)
# PREMCO GLOBAL
# PRIME GLORIOUS (VIETNAM)PANY
# PT . INDO - RAMA SYNTHETICS TBK
# PT ASIA PACIFIC FIBERS TBK
# PT INDO - RAMA SYNTHETICS TBK
# PT INDORAMA POLYCHEM INDONESIA
# PT INDORAMA SYNTHETICS TBK
# PT INDORAMA VENTURES INDONESIA
# PT YKK ZIPPER INDONESIA
# PT. ASIA PACIFIC FIBER TBK
# PT. DELTA DUNIA SANDANG TEKSTIL
# PT. DONG JIN TEXTILE INDONESIA
# PT. GISTEX CHEWON SYNTHETIC
# PT. INDORAMA POLYCHEM INDONESIA
# PT. INDO - RAMA SYNTHETICS TBK
# PT. OST FIBER INDUSTRIES
# PT. YKK ZIPPER INDONESIA
# PT.ASIA PACIFIC FIBERS TBK
# PT.DELTA MERLIN SANDANG TEKSTIL
# PT.DELTA TEKSTIL
# PT.GISTEX CHEWON SYNTHETIC
# PT.INDO - RAMA SYNTHETICS TBK
# PT.MUTU GADING TEKSTIL
# PT.SEYOUNG INDUSTRY
# PT.SILVER KRIS
# PT.TIFICO FIBER INDONESIA TBK
# PUTIAN CITY HANJIANG SANQUAN TRADING
# PYS HIGH - TECH
# QIANSIFANG SPECIAL FIBER (SUZHOU)
# QIAO ZHI MEI EYELASH FACTORY
# QINGDAO ANXUAN INTERNATIONAL TRADING
# QINGDAO HENGZHAO IMPORT & EXPORT
# QINGDAO JIFA IMP. & EXP
# QINGDAO JINXINYUANTONG INTERNATIONAL TRADE
# QINGDAO PAMPAS ECONOMIC & TRADE
# QINGDAO ROY - NE KNITTING
# QINGDAO TOPFIBRE
# QINGZHOU FOREIGN TRADEPORATION
# QINGZHOU HUASHENG TEMPERATURETROL EQUIPMENT
# QUADRILLE NISHIDA
# QUANZHOU HUAMIN TECHNOLOGY
# QUANZHOU JINBO KAIXUAN TRADING
# QUANZHOU MINMETALS (GROUP)P
# QUEEN SPEEDER
# R.P.T TRADING
# RAJ SYNTHETICS
# RAMATEX TEXTILES INDUSTRIAL SDN. BHD
# RAMESWAR UDYOG PRIVATE
# RAYHO
# RECRON (MALAYSIA) SDN. BHD (COMPANY NO. 781769 - K)
# RECRON (MALAYSIA) SDN. BHD
# RECRON (MALAYSIA) SND.BHD (COMPANY NO.781769 - K)
# RELIANCE INDUSTRIES
# RICHLON ENTERPRISEPANY
# RIEKER OBUV S.R.O
# RIEKER TRADING (SHENZHEN)
# RONGSHENG PETROCHEMICAL
# ROYAL SPIRIT
# RUENTEX INDUSTRIES
# S.A DEVELOPMENT/ YAGI &PANY
# S.RAJA EXPORT PVT
# SALONASPIN
# SAM LUNG PRODUCTS
# SAMIL KNIT
# SAMIL SPINNING
# SAMJIN TEXTILE
# SAMMYUNG TRADING
# SAMSUNG C & TPORATION
# SAMWON TRADING
# SAMWOO ENTERPRISE
# SAMYANGERING
# SAN FANG CHEMICAL
# SAN - ETSU
# SANGEETH TEXTILES PRIVATE
# SANKEI
# SARLA PERFORMANCE FIBERS
# SASAME TRADING
# SAWADA
# SBBINE.INC
# SCEND HANG INTERNATIONAL
# SDC (HONGKONG)PORATION
# SEONG - AN SYNTHETICS
# SEVEN O'CLOCK RESOURCES
# SEWANG TEXTILE
# SEYANG WIG HOUSE
# SGR TEXTILE HOUSE LLP
# SHAN LI (HK) WEBBING
# SHANDONG LUFENG INTELLIGENT EQUIPMENT
# SHANDONG SINOPLUS INTERNATIONAL TRADING
# SHANGHAI CHANCO IMPORT EXPORT CO
# SHANGHAI EAST BEST FOREIGN TRADE
# SHANGHAI META - TEX METALLIC YARN
# SHANGHAI MITSUBOSHI TRADIN CI.LTD
# SHANGHAI SANKEI GARMENTS & AUXILIARY
# SHANGHAI SHIQIAO IMPORT & EXPORT
# SHANGHAI TONGXIANG TEXTILE MACHINERY
# SHANGHAI VICO INDUSTRIAL
# SHAOXINGOUR CUBE TEXTILE
# SHAOXING FEIXUN NEW FURNITURECO
# SHAOXING GLOBAL CHEMICAL FIBER CO
# SHAOXING GOLDEN GULF IMPORT & EXPORT
# SHAOXING HONGSU TRADE
# SHAOXING HOUTAN TEXTILE
# SHAOXING HUAMAO POLYESTER
# SHAOXING JILOFU TRADE
# SHAOXING JINSHENG TEXTILE
# SHAOXING KEQIAO QINYUANCHUN IMP & EXP
# SHAOXING KEQIAO ZHIYUAN KNITTING
# SHAOXING PANTIAN CHEMICAL FIBER
# SHAOXING PUHONG TEXTILE
# SHAOXING QIER TRADING
# SHAOXING RUI YU TEXTILES
# SHAOXING SANYOU TEXTILE
# SHAOXING XINGJI IMPORT & EXPORT
# SHEICO GROUP (SHEI CHUNG HSIN IND.)
# SHEN ZHEN GNG
# SHENZHEN SHENDASHENG IMPORT & EXPORT
# SHENZHEN XIEXING TEXTILE
# SHERRY INDUSTRIAL HK
# SHI ZHAN TEXTILE
# SHIKIBO
# SHIMA SEIKI MFG
# SHINING LABLES MANUFACTURING
# SHINJIN TEX
# SHINJINTEX
# SHINKONG SYNTHETIC FIBERSP
# SHOWA BEST GLOVE
# SHREEDHARSYN PRIVATE
# SHREWTON OVERSEAS
# SHRISTISPINN PRIVATE
# SHUANGYI INDUSTRIES HOLDING
# SIAM MODERNTEX
# SINCETECH (FUJIAN) TECHNOLOGY
# SINGTEX INDUSTRIAL
# SINO - BEST INDUSTRIES
# SINTERAMA ASIA
# SIRIS (GANGLONG) KNITTING
# SKY VISION INTL
# SMARTEX SOLUTION TAIWAN
# SML (USA)
# SOFEENE ENTERPRISES
# SOLSANG INTERNATIONALP
# SONGWOL TOWEL
# SPRING TEXTILE HK
# SRI MUANG THAI (2525)
# SRI NUKALA RAMA KOTESWARA RAO TEXTILES PVT
# SS TEXTILE
# STAR INTERNATIONAL TRADE (CHANGZHOU)
# STARFLEX (VIETNAM)
# SUDIMA INTERNATIONAL
# SUE'S INTERNATIONALP
# SUE'S INTERNATIONALP/ DET NHUOM QUOC TE RADIANT
# SUMTEX INDUSTRIAL
# SUN SUN (HK) MANUFACTURING
# SUN WAN INTERNATIONAL
# SUNCORONA ODA
# SUNG HO ACCESSORIES
# SUNG HWA TRADING
# SUNHO TEXTILE DYEING L TD
# SUNJIN AT & C
# SUNJIN TEXTILE CO
# SUNRAY MACAOMERCIAL
# SUNRISE TEXTILES GROUP TRADING (HK)
# SUZHOU CHAMELEON FIBER DYEING
# SUZHOU CHUNSHENG ENVIRONMENTAL PROTECTION FIBER
# SUZHOU FINETEX SCIENCE & TECHNOLOGY
# SUZHOU GEDO ADVANCED TEXTILE
# SUZHOU GLORY
# SUZHOU GUOXIN GROUP FENGYUAN IMP & EXP
# SUZHOU HONGJU FIBER TECHNOLOGY
# SUZHOU INDUSTRIAL PARK SHENGOU TEXTILE
# SUZHOU JUNHUI TEXTILE
# SUZHOU NON - SUCCESS EVERYE INTERNATIONAL TRADING
# SUZHOU SHENGHONG FIBER
# SUZHOU UNIVERSE IMPORT & EXPORT
# SUZHOU YALEN TEXTILE TECHNOLOGY
# SUZHOU YU NIAN SHUI FIBER TECHNOLOGYPANY
# SUZHOU YUNHONG INTERNATIONAL TRADE
# SZ YAFUINTELLIGENT TECHNOGY
# TAE KYUNGPANY
# TAI TEXTILES
# TAICANG SANHUI TRADING
# TAICANG XINYUE CHEMICAL FIBER
# TAICHUNG SHUI HING LABEL WEAVING
# TAIWAN CHORI MERCHANDISEPERATION
# TAIWAN PAIHO
# TAIWAN TAFFETA FABRIC
# TAIWAN YAMANI
# TAMURAKOMA &
# TE LIN TRADING
# TECHNOW SHANGHAI
# TEIJIN FRONTIER (SHANGHAI)
# TEIJINFRONTIER
# TENTAC (SHANGHAI)
# TEXET
# TEXON ITALIA SRL
# TEXPERT SA DE CV
# TEXTILE DEPO
# TEXVISTA INTERNATIONAL
# TEXVISTA INTERNATIONAL.LTD
# THAI ASAHI KASEI SPANDEX
# THAI KURABO
# THAI MAN INDUSTRIES
# THAI POLYESTER
# THAI TORAY SYNTHETICS
# THAIMAN INDUSTRIES
# THANG QUAN
# THAR TARAY SYNLHETICSLTD
# THE LYCRAPANY
# THE WORLDPANY
# THREE YUEAN INDUSTRIAL
# TIANJIN GLORY TANG TEXTILE
# TIANJIN POLYSTAR TEXTILE IMPORT & EXPORT
# TIANJIN XINYU TEXTILE
# TIONG LIONG INDUSTRIAL
# TOHITOMO
# TOKIN ELECTRONICS (XIAMEN)PORATION
# TOKYO ROPE MFG
# TOMOE SANGYO
# TONG DE HEPANY
# TONGKUN GROUP
# TONGXIANG ZHONGCHEN CHEMICAL FIBER
# TOP STAR TEXTILE
# TORAY ADVANCED FURNITURE KOREA
# TORAY FIBERS (NANTONG)
# TORAY IND. WOMEN'S & MEN'S WEA
# TORAY INDUSTRIES (H.K.)
# TORAY INTERNATIONAL (CHINA)
# TORAY INTERNATIONALINC
# TORAY TEXTILES (THAILAND) PLC
# TORAY TEXTILES
# TOSCOM
# TOUNG LOONG TEXTILE MFG
# TOYO TEXTILE
# TOYOBO STC
# TOYOSHIMA
# TOYOTA TSUSHOPORATION
# TPS KOREA
# TRANSTEC INTERNATIONAL
# TREASURE STAR INTERNATIONALP
# TSAI YIN - SHUN
# TSUCHIYA TSCO
# TSUKASA - PROGRESS
# TUGTEKS TEKSTIL IPLIK SAN.VE TIC.LTD.STI
# TUNG ZHU INDUSTRIAL
# TUNTEXORPORATION
# UFUK SHANGHAI
# UHPORATION
# ULHWAPORATION
# UNIFI MANUFACTURING
# UNIFI TEXTILES (SUZHOU)
# UNISKY SHANGHAI (HK)
# UNITIKA TRADING
# UNIVERSAL STARPORATION
# UNO &PANY
# VEKSTAR TEXTILE (SHANGHAI)
# VESTERGAARD SARL
# VI THANH
# VICTOR TRADE (NINGBO)
# VIETNAM PAIHO
# VINA STAR INTERNATIONAL
# VINH SAN
# VOLANT MANUFACTURING INTERNATIONALP
# VORTEX INTERNATIONAL
# WAMPUM SYNTEX
# WE WILL (XIAMEN) TECHNOLOGY
# WEEKLY PLAN
# WEIHAI XINLONG FIBER
# WEIQIAO TEXTILEPANY
# WEITEX
# WELCRON
# WELLSUM TRADINGPANY
# WHASUN TECHPORATION
# WILSON INDUSTRIAL (JIANG XI)
# WING TAK INDUSTRIALPANY
# WINNER UNITED
# WINWIN TEX
# WONDER LINK ENTERPRISE
# WORLD ONE TRADING
# WORLDTEX ENTERPRISES (HONG KONG)
# WTL
# WUJIANG JIALI ADVANCED FIBER
# WUXI MAEDA TEXTILE & CHEMICAL
# WUXI TONGDA TELECOMMUNICATION ACCESSORIES FACTORY
# WUXI XINGSHENG NEW FURNITURETECHNOLOGY
# XIAMEN CHANQUAN TECHNOLOGY
# XIAMEN CHENGFENGRUI TRADE
# XIAMEN EXCEL TEX TECHNOLOGY
# XIAMEN EXCELTEX TECHNOLOGY
# XIAMEN FU MAO LONG FIBER MATERIALCO.LTD
# XIAMEN HUIZHIMIN IMP. & EXP
# XIAMEN JIAWO TRADINGPANY
# XIAMEN JIN XIA TECHNOLOGY
# XIAMEN JINXIA TECHNOLOGY
# XIAMEN JOIN - PROFIT TRADE
# XIAMEN LA RIBBON & CRAFT
# XIAMEN PHOENIX NEW FURNITURETECHNOLOGY
# XIAMEN SINBOO TECHNOLOGY
# XIAMEN TENGFEI IMP. & EXP
# XIAMEN WEITAI TEXTILE TECH
# XIAMEN XIANGLU CHEMICAL FIBER
# XIAMEN XIANGYUXINGHONG SPECIALISED MATERIALS
# XIAMEN YUEBANG TRADE
# XIANGLU FIBERS (HAICHENG)
# XIN FENGMING GROUP
# XINFENGMING GROUP HUZHOU ZHONGSHI TECHNOLOGY
# XUYUANDA SHOE (HONG KONG)
# YAGI &(HK)
# YAGI &
# YAGI &/TENTAC (HO CHI MINH)
# YAKJIN TRADINGPORATION
# YARN ONE TRADINGPANY
# YI SHIN TEXTILE INDUSTRIAL
# YIBIN MERRY TRADING
# YIWUORWAY TRADE
# YMSA
# YORNG SHENG INTERNATIONAL
# YOUNGDONG WEBBING
# YOUNGJIN TEX
# YOUNGONE NAMDINH
# YOUNGONE OUTDOORPORATION
# YOUNGWOO KOREA STM
# YS INTERNATIONAL
# YU LIN CITY YISHENG TEXTILE TECHNOLOGY
# YU YUANG TEXTILE
# YUNG CHANG LABEL
# YY POLYESTER
# ZEN - FA FIBER
# ZENITH INVESTMENTS
# ZHANGJIAGANG BONDED ZONE JUNYIXUAN INTERNATIONAL TRADING
# ZHANGJIAGANG HENGMEI TEXTILE
# ZHEJIANG CADY INDUSTRY
# ZHEJIANG DOEAST INTERNATIONAL TRADE
# ZHEJIANG DOEAST THREADPANY
# ZHEJIANG FREE TRADE ZONE SOLEADMERCE & TRADING
# ZHEJIANG GUXIANDAO POLYESTER DOPE DYED YARN
# ZHEJIANG HAILI ENVIRONMENTAL TECHNOLOGY
# ZHEJIANG HENGYI PETROCHEMICALS
# ZHEJIANG HENGYOU CHEMICALS FIBER
# ZHEJIANG HUAFON SPANDEX
# ZHEJIANG HUILONG NEW MATERIALS
# ZHEJIANG JASAN HOLDING GROUP
# ZHEJIANG JIABAO POLYESTER
# ZHEJIANG JIAREN NEW MATERIALS
# ZHEJIANG KARL NECKTIE & DRESS
# ZHEJIANG PRAITE TEXTILE
# ZHEJIANG SANWEI FURNITURETECHNOLOGY
# ZHEJIANG SENKAI NEW MATERIALS
# ZHEJIANG SHANGYUAN CHEMICAL FIBER
# ZHEJIANG UNIFULL INDUSTRIAL FIBER
# ZHEJIANG XINGHUALI FIBER
# ZHEJIANG ZHUJI HANYOU IMPORT & EXPORT
# ZHEJIANGJINXIAXINCAILIAOKEJIYOUXIANGONGSI
# ZHONGKAIMERCELIMITED - IA
# ZHONGSHAN SERAM ACCESSORIES
# ZHUCHENG FUBER TEXTILE TECHNOLOGY
# ZHUJI ZANSHENG IMPORT & EXPORT
# ZHUJI BAIFUQIN TRADE
# ZHUJI BIYUAN IMP EXP
# ZHUJI BIYUAN IMPORT & EXPORTLT
# ZHUJI JIEYI TRADING
# ZHUJI MINGYI IMPORT & EXPORT
# ZIG SHENG INDUSTRIAL
